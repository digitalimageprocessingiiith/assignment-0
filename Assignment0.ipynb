# %% [markdown]
# <a href="https://colab.research.google.com/github/cryptpuru/src/blob/main/Assignment0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Numpy as np
# Import opencv as cv2
# cv2_imshow is not working colab so from google.colab.patches import cv2_imshow
# load the image into variable img
# use cv2_imshow to show the image

# %% [markdown]
# using git
# git clone _ downloads repository on local
# git add - adds the repository to add
# git commit - saves the changes on git
# git push origin
# git pull

# %% [markdown]
# Github classroom
# invitation link will be sent
# choose your roll number
# private repository
# keep commiting work
# make ur final commmit before the deadline
# directly clone it to github

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/Jaguar.jpg",0)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=800x500 at 0x7F80321ABD90>

# %% [markdown]
#   Numpy and Opencv will be extensively used
#   when not mentioned do not used opencv
#   Other libraries include
#   scikit learn scikit image PIL
#   edureka data structure in python
#   (import os)
#
# ###Heading
# #head
# ##hea

# %% [markdown]
# np.linspace range space number of coulmns |
# gives equally spaced numbers

# %% [markdown]
# ##Matplotlib
# to plot the image |
# graph plotting |
# use labels when plotting graphs |
# add sublot 221 means position 1 in 2x2 matrix |

# %% [markdown]
# ##Plotly
# interactive plots |

# %% [markdown]
# ###BGR to RGB for colour correction

# %% [markdown]
# cmpap = gray changes image to gray

# %% [markdown]
# print as gray | Convert it to gray | Store it as gray
